# %% [markdown]
# # Flanders Make Scientific Conference 2026 Tutorial: Understand, transform, and enrich your tables with LLMs

# %% [markdown]
# Demo description...

# %% [markdown]
# ### Visualize table

# %%
import pandas as pd

# %%
# Open aircraft csv 
aircraft_file_path = 'data/sfo-aircraft-tail-numbers-and-models.csv'
lines_to_keep = 100
df = pd.read_csv(aircraft_file_path, index_col=False)
df = df.head(lines_to_keep)[["aircraft_model", "airline", "creation_date"]]
df = df.replace(',', '', regex=True)

aircraft_file_path_simple = 'data/aircraft_models.csv'
df.to_csv(aircraft_file_path_simple, index=False)
df
# Out:
#    aircraft_model                   airline            creation_date
# 0         CRJ-700          Skywest Airlines  2009-09-10T16:33:00.000
# 1           E175-          Skywest Airlines  2018-04-23T08:34:00.000
# 2        B747-400  KLM Royal Dutch Airlines  2018-04-14T16:49:00.000
# 3        B737-700        Southwest Airlines  2018-03-17T17:20:00.000
# 4        A320-200           United Airlines  2011-08-23T19:20:00.000
# ..            ...                       ...                      ...
# 95       B747-400            Qantas Airways  2009-06-11T02:55:00.000
# 96       B767-200                  Amerijet  2009-11-25T16:10:00.000
# 97        EMB-120          Skywest Airlines  2014-11-01T12:16:00.000
# 98        CRJ-200          Skywest Airlines  2014-04-01T08:35:00.000
# 99       A350-900            Cathay Pacific  2017-12-30T07:08:00.000
#
# [100 rows x 3 columns]

# %% [markdown]
# ### Table Understanding with TorchicTab

# %%
from torchic_tab_heuristic.task_calculation_wd import generate_annotations 

use_es_index = False

(subject_column, 
 primary_annotations, 
 secondary_annotations, 
 cea, 
 cpa, 
 cta) = generate_annotations(aircraft_file_path_simple, use_es_index)
# Out:
# TorchicTab Initiated!
# Loading table...
# Table: data/aircraft_models.csv
#     aircraft_model                   airline creation_date
# 0         CRJ-700          Skywest Airlines    2009-09-10
# 1           E175-          Skywest Airlines    2018-04-23
# 2        B747-400  KLM Royal Dutch Airlines    2018-04-14
# 3        B737-700        Southwest Airlines    2018-03-17
# 4        A320-200           United Airlines    2011-08-23
# ..            ...                       ...           ...
# 95       B747-400            Qantas Airways    2009-06-11
# 96       B767-200                  Amerijet    2009-11-25
# 97        EMB-120          Skywest Airlines    2014-11-01
# 98        CRJ-200          Skywest Airlines    2014-04-01
# 99       A350-900            Cathay Pacific    2017-12-30
#
# [100 rows x 3 columns]
#
# Calculating structural annotations...
# Calculating semantic annotations...
#
#
#
# Candidates searching...
#
#
#
# Context score estimation...
#
#
#
# CPA calculation...
#
#
#
# CEA calculation...
#
#
#
# CTA calculation...
# Exporting all annotations...

# %% [markdown]
# Export annotations for reproducibility

# %%
import json

def save_json(filename, data):
    """
    Save data to a JSON file.
    """
    with open(filename, "w") as f:
        json.dump(data, f, indent=4)

    return


def load_json(filename):
    """
    Load data from a JSON file.
    """
    with open(filename, "r") as f:
        data = json.load(f)
    return data

# %%
annotations = {}
annotations["subject_column"] = subject_column
annotations["primary_annotations"] = primary_annotations
annotations["secondary_annotations"] = secondary_annotations
annotations["cea"] = cea
annotations["cpa"] = cpa
annotations["cta"] = cta
annotations["cqa"] = []
save_json("annotations/annotations3.json", annotations)

# %%
# Get subject column of table
print(f"The subject column of the table is column: \n {df.iloc[:, subject_column]}")
# Out:
# The subject column of the table is column:
#  0      CRJ-700
# 1        E175-
# 2     B747-400
# 3     B737-700
# 4     A320-200
#         ...
# 95    B747-400
# 96    B767-200
# 97     EMB-120
# 98     CRJ-200
# 99    A350-900
# Name: aircraft_model, Length: 100, dtype: object

# %%
# Get generic semantic annotations of table
print("Generic column annotations:")
for i in range(len(df.columns)):
    print("\n",df.columns[i])
    print(df.iloc[:, i])
    print(f"Generic semantic type: {secondary_annotations[i]}")
# Out:
# Generic column annotations:
#
#  aircraft_model
# 0      CRJ-700
# 1        E175-
# 2     B747-400
# 3     B737-700
# 4     A320-200
#         ...
# 95    B747-400
# 96    B767-200
# 97     EMB-120
# 98     CRJ-200
# 99    A350-900
# Name: aircraft_model, Length: 100, dtype: object
# Generic semantic type: NE
#
#  airline
# 0             Skywest Airlines
# 1             Skywest Airlines
# 2     KLM Royal Dutch Airlines
# 3           Southwest Airlines
# 4              United Airlines
#                 ...
# 95              Qantas Airways
# 96                    Amerijet
# 97            Skywest Airlines
# 98            Skywest Airlines
# 99              Cathay Pacific
# Name: airline, Length: 100, dtype: object
# Generic semantic type: ORG
#
#  creation_date
# 0     2009-09-10T16:33:00.000
# 1     2018-04-23T08:34:00.000
# 2     2018-04-14T16:49:00.000
# 3     2018-03-17T17:20:00.000
# 4     2011-08-23T19:20:00.000
#                ...
# 95    2009-06-11T02:55:00.000
# 96    2009-11-25T16:10:00.000
# 97    2014-11-01T12:16:00.000
# 98    2014-04-01T08:35:00.000
# 99    2017-12-30T07:08:00.000
# Name: creation_date, Length: 100, dtype: object
# Generic semantic type: DATE

# %%
# Get column type annotations
print("Column type annotations:")
for type_annotation in cta:
    column = int(type_annotation[0])
    annotation = type_annotation[1]
    print("\n",df.columns[column])
    print(df.iloc[:, column])
    print(f"Generic semantic type: {secondary_annotations[column]}")
    print(f"Wikidata retrieved annotation: {annotation}")
# Out:
# Column type annotations:
#
#  aircraft_model
# 0      CRJ-700
# 1        E175-
# 2     B747-400
# 3     B737-700
# 4     A320-200
#         ...
# 95    B747-400
# 96    B767-200
# 97     EMB-120
# 98     CRJ-200
# 99    A350-900
# Name: aircraft_model, Length: 100, dtype: object
# Generic semantic type: NE
# Wikidata retrieved annotation: http://www.wikidata.org/entity/Q15056993
#
#  airline
# 0             Skywest Airlines
# 1             Skywest Airlines
# 2     KLM Royal Dutch Airlines
# 3           Southwest Airlines
# 4              United Airlines
#                 ...
# 95              Qantas Airways
# 96                    Amerijet
# 97            Skywest Airlines
# 98            Skywest Airlines
# 99              Cathay Pacific
# Name: airline, Length: 100, dtype: object
# Generic semantic type: ORG
# Wikidata retrieved annotation: http://www.wikidata.org/entity/Q46970

# %%
# Get column relationship annotations
print("Column relationships:")
for rel_annotation in cpa:
    if rel_annotation[2][-3:] == "/P1": continue #unkown relationship
    col1 = int(rel_annotation[0])
    col2 = int(rel_annotation[1])
    relationship = rel_annotation[2]
    print(f"\nColumn: {df.columns[col1]} --> {relationship} --> Column: {df.columns[col2]}")
# Out:
# Column relationships:
#
# Column: aircraft_model --> http://www.wikidata.org/prop/direct/P137 --> Column: airline

# %%
# Get cell annotations
print("Cell entity annotations:")
for cell_annotation in cea:
    col = int(cell_annotation[1])
    row = int(cell_annotation[0]) - 1
    annotation = cell_annotation[2]
    print(f"\nColumn: {df.columns[col]}")
    print(f"Cell name: '{df.iloc[row, col]}' --> Annotation: {annotation}")
# Out:
# Cell entity annotations:
#
# Column: aircraft_model
# Cell name: 'CRJ-700' --> Annotation: http://www.wikidata.org/entity/Q962677
#
# Column: aircraft_model
# Cell name: 'E175-' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B737-700' --> Annotation: http://www.wikidata.org/entity/Q15623371
#
# Column: aircraft_model
# Cell name: 'A320-200' --> Annotation: http://www.wikidata.org/entity/Q15629179
#
# Column: aircraft_model
# Cell name: 'SHORTS-360' --> Annotation: http://www.wikidata.org/entity/Q2140324
#
# Column: aircraft_model
# Cell name: 'B737-800' --> Annotation: http://www.wikidata.org/entity/Q12476717
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'CRJ-700' --> Annotation: http://www.wikidata.org/entity/Q962677
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'A350-900' --> Annotation: http://www.wikidata.org/entity/Q6484
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'A300-B2' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'A321-200' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'B747-400ER' --> Annotation: http://www.wikidata.org/entity/Q15630770
#
# Column: aircraft_model
# Cell name: 'B767-400ER' --> Annotation: http://www.wikidata.org/entity/Q15624006
#
# Column: aircraft_model
# Cell name: 'B737-700' --> Annotation: http://www.wikidata.org/entity/Q15623371
#
# Column: aircraft_model
# Cell name: 'B787-9' --> Annotation: http://www.wikidata.org/entity/Q15111575
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'B717-' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'A330-200' --> Annotation: http://www.wikidata.org/entity/Q68189256
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'CRJ-900' --> Annotation: http://www.wikidata.org/entity/Q4572676
#
# Column: aircraft_model
# Cell name: 'B767-400ER' --> Annotation: http://www.wikidata.org/entity/Q15624006
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'B787-9' --> Annotation: http://www.wikidata.org/entity/Q15111575
#
# Column: aircraft_model
# Cell name: 'CRJ-900' --> Annotation: http://www.wikidata.org/entity/Q4572676
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'A350-900' --> Annotation: http://www.wikidata.org/entity/Q6484
#
# Column: aircraft_model
# Cell name: 'B737-900' --> Annotation: http://www.wikidata.org/entity/Q15623378
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'B737-900' --> Annotation: http://www.wikidata.org/entity/Q15623378
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'A320-200' --> Annotation: http://www.wikidata.org/entity/Q15629179
#
# Column: aircraft_model
# Cell name: 'E175-' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B767-300' --> Annotation: http://www.wikidata.org/entity/Q15623997
#
# Column: aircraft_model
# Cell name: 'B787-9' --> Annotation: http://www.wikidata.org/entity/Q15111575
#
# Column: aircraft_model
# Cell name: 'DC8-73F' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'A350-900' --> Annotation: http://www.wikidata.org/entity/Q6484
#
# Column: aircraft_model
# Cell name: 'B737-800' --> Annotation: http://www.wikidata.org/entity/Q12476717
#
# Column: aircraft_model
# Cell name: 'B737-900' --> Annotation: http://www.wikidata.org/entity/Q15623378
#
# Column: aircraft_model
# Cell name: 'B737-900' --> Annotation: http://www.wikidata.org/entity/Q15623378
#
# Column: aircraft_model
# Cell name: 'A330-300' --> Annotation: http://www.wikidata.org/entity/Q62274649
#
# Column: aircraft_model
# Cell name: 'A350-900' --> Annotation: http://www.wikidata.org/entity/Q6484
#
# Column: aircraft_model
# Cell name: 'A321-200' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B737-700' --> Annotation: http://www.wikidata.org/entity/Q15623371
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'CRJ-900' --> Annotation: http://www.wikidata.org/entity/Q4572676
#
# Column: aircraft_model
# Cell name: 'A321-200' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'A350-900' --> Annotation: http://www.wikidata.org/entity/Q6484
#
# Column: aircraft_model
# Cell name: 'A319-' --> Annotation: http://www.wikidata.org/entity/Q15629580
#
# Column: aircraft_model
# Cell name: 'A300-600' --> Annotation: http://www.wikidata.org/entity/Q11289451
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'B737-900' --> Annotation: http://www.wikidata.org/entity/Q15623378
#
# Column: aircraft_model
# Cell name: 'B767-400ER' --> Annotation: http://www.wikidata.org/entity/Q15624006
#
# Column: aircraft_model
# Cell name: 'A321-200' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B737-700' --> Annotation: http://www.wikidata.org/entity/Q15623371
#
# Column: aircraft_model
# Cell name: 'B737-900' --> Annotation: http://www.wikidata.org/entity/Q15623378
#
# Column: aircraft_model
# Cell name: 'E175-' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'MD-11' --> Annotation: http://www.wikidata.org/entity/Q15947297
#
# Column: aircraft_model
# Cell name: 'MD-11' --> Annotation: http://www.wikidata.org/entity/Q15947297
#
# Column: aircraft_model
# Cell name: 'MD-11' --> Annotation: http://www.wikidata.org/entity/Q15947297
#
# Column: aircraft_model
# Cell name: 'MD-11' --> Annotation: http://www.wikidata.org/entity/Q15947297
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'E175-' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B767-300' --> Annotation: http://www.wikidata.org/entity/Q15623997
#
# Column: aircraft_model
# Cell name: 'CRJ-900' --> Annotation: http://www.wikidata.org/entity/Q4572676
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'B737-800' --> Annotation: http://www.wikidata.org/entity/Q12476717
#
# Column: aircraft_model
# Cell name: 'E175-' --> Annotation: None
#
# Column: aircraft_model
# Cell name: 'B777-300' --> Annotation: http://www.wikidata.org/entity/Q31190031
#
# Column: aircraft_model
# Cell name: 'B737-800' --> Annotation: http://www.wikidata.org/entity/Q12476717
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'CRJ-100' --> Annotation: http://www.wikidata.org/entity/Q9177195
#
# Column: aircraft_model
# Cell name: 'B737-800' --> Annotation: http://www.wikidata.org/entity/Q12476717
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'B747-400' --> Annotation: http://www.wikidata.org/entity/Q906937
#
# Column: aircraft_model
# Cell name: 'B767-200' --> Annotation: http://www.wikidata.org/entity/Q15623987
#
# Column: aircraft_model
# Cell name: 'EMB-120' --> Annotation: http://www.wikidata.org/entity/Q1163407
#
# Column: aircraft_model
# Cell name: 'CRJ-200' --> Annotation: http://www.wikidata.org/entity/Q891786
#
# Column: aircraft_model
# Cell name: 'A350-900' --> Annotation: http://www.wikidata.org/entity/Q6484
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'KLM Royal Dutch Airlines' --> Annotation: http://www.wikidata.org/entity/Q96371601
#
# Column: airline
# Cell name: 'Southwest Airlines' --> Annotation: http://www.wikidata.org/entity/Q503308
#
# Column: airline
# Cell name: 'United Airlines' --> Annotation: http://www.wikidata.org/entity/Q174769
#
# Column: airline
# Cell name: 'DHL Express (USA)' --> Annotation: http://www.wikidata.org/entity/Q610190
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Evergreen International Airlines' --> Annotation: http://www.wikidata.org/entity/Q1188127
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Cathay Pacific' --> Annotation: http://www.wikidata.org/entity/Q32141
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Swissport USA' --> Annotation: http://www.wikidata.org/entity/Q680965
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'Emirates ' --> Annotation: http://www.wikidata.org/entity/Q180432
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Nippon Cargo Airlines' --> Annotation: http://www.wikidata.org/entity/Q1364998
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'Southwest Airlines' --> Annotation: http://www.wikidata.org/entity/Q503308
#
# Column: airline
# Cell name: 'Virgin Atlantic' --> Annotation: http://www.wikidata.org/entity/Q32277
#
# Column: airline
# Cell name: 'Korean Air Lines' --> Annotation: http://www.wikidata.org/entity/Q213147
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'American Airlines' --> Annotation: http://www.wikidata.org/entity/Q32396
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'United Airlines' --> Annotation: http://www.wikidata.org/entity/Q174769
#
# Column: airline
# Cell name: 'Korean Air Lines' --> Annotation: http://www.wikidata.org/entity/Q213147
#
# Column: airline
# Cell name: 'Air Canada' --> Annotation: http://www.wikidata.org/entity/Q1458703
#
# Column: airline
# Cell name: 'Qantas Airways' --> Annotation: http://www.wikidata.org/entity/Q32491
#
# Column: airline
# Cell name: 'Cathay Pacific' --> Annotation: http://www.wikidata.org/entity/Q32141
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Korean Air Lines' --> Annotation: http://www.wikidata.org/entity/Q213147
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Swissport USA' --> Annotation: http://www.wikidata.org/entity/Q680965
#
# Column: airline
# Cell name: 'Air Canada' --> Annotation: http://www.wikidata.org/entity/Q1458703
#
# Column: airline
# Cell name: 'Horizon Air ' --> Annotation: http://www.wikidata.org/entity/Q1200062
#
# Column: airline
# Cell name: 'Atlas Air Inc' --> Annotation: http://www.wikidata.org/entity/Q757135
#
# Column: airline
# Cell name: 'Korean Air Lines' --> Annotation: http://www.wikidata.org/entity/Q213147
#
# Column: airline
# Cell name: 'Swissport USA' --> Annotation: http://www.wikidata.org/entity/Q680965
#
# Column: airline
# Cell name: 'Asiana Airlines' --> Annotation: http://www.wikidata.org/entity/Q211165
#
# Column: airline
# Cell name: 'Southwest Airlines' --> Annotation: http://www.wikidata.org/entity/Q503308
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Hawaiian Airlines' --> Annotation: http://www.wikidata.org/entity/Q642610
#
# Column: airline
# Cell name: 'Cathay Pacific' --> Annotation: http://www.wikidata.org/entity/Q32141
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'Southwest Airlines' --> Annotation: http://www.wikidata.org/entity/Q503308
#
# Column: airline
# Cell name: 'Singapore Airlines' --> Annotation: http://www.wikidata.org/entity/Q32245
#
# Column: airline
# Cell name: 'Qantas Airways' --> Annotation: http://www.wikidata.org/entity/Q32491
#
# Column: airline
# Cell name: 'Korean Air Lines' --> Annotation: http://www.wikidata.org/entity/Q213147
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Air Canada' --> Annotation: http://www.wikidata.org/entity/Q1458703
#
# Column: airline
# Cell name: 'JetBlue Airways' --> Annotation: http://www.wikidata.org/entity/Q161086
#
# Column: airline
# Cell name: 'Cathay Pacific' --> Annotation: http://www.wikidata.org/entity/Q32141
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'Air China' --> Annotation: http://www.wikidata.org/entity/Q51747
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Delta Air Lines' --> Annotation: http://www.wikidata.org/entity/Q188920
#
# Column: airline
# Cell name: 'Virgin America' --> Annotation: http://www.wikidata.org/entity/Q645084
#
# Column: airline
# Cell name: 'Sun Country Airlines' --> Annotation: http://www.wikidata.org/entity/Q866289
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Compass Airlines' --> Annotation: http://www.wikidata.org/entity/Q5156076
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'United Airlines' --> Annotation: http://www.wikidata.org/entity/Q174769
#
# Column: airline
# Cell name: 'Compass Airlines' --> Annotation: http://www.wikidata.org/entity/Q5156076
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'EVA Airways' --> Annotation: http://www.wikidata.org/entity/Q715113
#
# Column: airline
# Cell name: 'DHL Express (USA)' --> Annotation: http://www.wikidata.org/entity/Q610190
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Korean Air Lines' --> Annotation: http://www.wikidata.org/entity/Q213147
#
# Column: airline
# Cell name: 'Alaska Airlines' --> Annotation: http://www.wikidata.org/entity/Q822614
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'China Airlines' --> Annotation: http://www.wikidata.org/entity/Q51756
#
# Column: airline
# Cell name: 'China Airlines' --> Annotation: http://www.wikidata.org/entity/Q51756
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Southwest Airlines' --> Annotation: http://www.wikidata.org/entity/Q503308
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Qantas Airways' --> Annotation: http://www.wikidata.org/entity/Q32491
#
# Column: airline
# Cell name: 'Amerijet' --> Annotation: http://www.wikidata.org/entity/Q901317
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Skywest Airlines' --> Annotation: http://www.wikidata.org/entity/Q773662
#
# Column: airline
# Cell name: 'Cathay Pacific' --> Annotation: http://www.wikidata.org/entity/Q32141

# %% [markdown]
# ### Enrich Table Leveraging Semantic Available Semantic Information

# %% [markdown]
# Since we have now matched airplanes and airlines with a large external knowledge base such as Wikidata,
# we can query this knowledge base to find out more information about our data and enrich them.

# %% [markdown]
# Wikidata plane attributes that maybe useful to include:
# - Plane first flight (Wikidata property P606)
# - Plane maximum operating altitude (Wikidata property P2254)
# - PLane height (Wikidata property P2048)
# - Plane length (Wikidata property P2043)

# %%
plane_column = 0
plane_entities = []
counter = 0
for cell_annotation in cea:
    
    col = int(cell_annotation[1])
    row = int(cell_annotation[0]) - 1
    annotation = cell_annotation[2]
    if col == 0: 
        counter += 1
        plane_entities.append(annotation)

plane_entities
# Out:
# ['http://www.wikidata.org/entity/Q962677',
#  None,
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q15623371',
#  'http://www.wikidata.org/entity/Q15629179',
#  'http://www.wikidata.org/entity/Q2140324',
#  'http://www.wikidata.org/entity/Q12476717',
#  'http://www.wikidata.org/entity/Q1163407',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q962677',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q6484',
#  'http://www.wikidata.org/entity/Q1163407',
#  None,
#  None,
#  'http://www.wikidata.org/entity/Q31190031',
#  'http://www.wikidata.org/entity/Q1163407',
#  'http://www.wikidata.org/entity/Q15630770',
#  'http://www.wikidata.org/entity/Q15624006',
#  'http://www.wikidata.org/entity/Q15623371',
#  'http://www.wikidata.org/entity/Q15111575',
#  'http://www.wikidata.org/entity/Q31190031',
#  None,
#  'http://www.wikidata.org/entity/Q68189256',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q4572676',
#  'http://www.wikidata.org/entity/Q15624006',
#  'http://www.wikidata.org/entity/Q31190031',
#  'http://www.wikidata.org/entity/Q15111575',
#  'http://www.wikidata.org/entity/Q4572676',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q6484',
#  'http://www.wikidata.org/entity/Q15623378',
#  'http://www.wikidata.org/entity/Q31190031',
#  'http://www.wikidata.org/entity/Q15623378',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q15629179',
#  None,
#  'http://www.wikidata.org/entity/Q15623997',
#  'http://www.wikidata.org/entity/Q15111575',
#  None,
#  'http://www.wikidata.org/entity/Q6484',
#  'http://www.wikidata.org/entity/Q12476717',
#  'http://www.wikidata.org/entity/Q15623378',
#  'http://www.wikidata.org/entity/Q15623378',
#  'http://www.wikidata.org/entity/Q62274649',
#  'http://www.wikidata.org/entity/Q6484',
#  None,
#  'http://www.wikidata.org/entity/Q15623371',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q31190031',
#  'http://www.wikidata.org/entity/Q1163407',
#  'http://www.wikidata.org/entity/Q4572676',
#  None,
#  'http://www.wikidata.org/entity/Q6484',
#  'http://www.wikidata.org/entity/Q15629580',
#  'http://www.wikidata.org/entity/Q11289451',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q15623378',
#  'http://www.wikidata.org/entity/Q15624006',
#  None,
#  'http://www.wikidata.org/entity/Q15623371',
#  'http://www.wikidata.org/entity/Q15623378',
#  None,
#  'http://www.wikidata.org/entity/Q15947297',
#  'http://www.wikidata.org/entity/Q15947297',
#  'http://www.wikidata.org/entity/Q15947297',
#  'http://www.wikidata.org/entity/Q15947297',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q31190031',
#  None,
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q15623997',
#  'http://www.wikidata.org/entity/Q4572676',
#  'http://www.wikidata.org/entity/Q1163407',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q12476717',
#  None,
#  'http://www.wikidata.org/entity/Q31190031',
#  'http://www.wikidata.org/entity/Q12476717',
#  'http://www.wikidata.org/entity/Q1163407',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q9177195',
#  'http://www.wikidata.org/entity/Q12476717',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q906937',
#  'http://www.wikidata.org/entity/Q15623987',
#  'http://www.wikidata.org/entity/Q1163407',
#  'http://www.wikidata.org/entity/Q891786',
#  'http://www.wikidata.org/entity/Q6484']

# %%
new_plane_properties = ["P606", "P2254", "P2048", "P2043", "P2050", "P1092", "P1083"]
new_plane_property_labels = ["first_flight", 
                             "maximum_operating_altitude(m)", 
                             "height(m)", 
                             "length(m)",
                             "wingspan(m)",
                             "total_produced",
                             "maximum_capacity"]
new_attributes = {property: [] for property in new_plane_property_labels}

# %%
#Create the corresponding  SPARQL query 
from SPARQLWrapper import SPARQLWrapper, JSON

def get_wikidata_object(entity, property):
    #Wikidata connection setup
    endpoint_url = "https://query.wikidata.org/sparql"
    sparql = SPARQLWrapper(endpoint_url)
    sparql.addCustomHttpHeader("User-Agent", "MyPythonApp/1.0 (ioannis.dasoulas@kuleuven.be)")

    #Query with a subject entity and object as inputs
    query = f"""
        SELECT ?object WHERE {{
            <{entity}> wdt:{property} ?object .
        }} LIMIT 1
        """
    
    # Query execution
    sparql.setQuery(query)
    sparql.setReturnFormat(JSON)

    # Results retrieval
    response = sparql.query().convert()
    try:
        results = response['results']['bindings']
        if results:
            return results[0]['object']['value']
        else:
            return None
    except Exception as e:
        print(f"Error querying {entity} for {property}: {e}")
        return None

# %%
# Extract new information with the constructed query 
print("Extracting new information for aircraft models...")
for i in range(len(plane_entities)): 
    for j in range(len(new_plane_properties)):
        print(f"\nPlane: {df['aircraft_model'].to_list()[i]}")
        print(f"Extracting {new_plane_property_labels[j].replace('_',' ')} data...")

        if plane_entities[i] is None: 
            print(f"No {new_plane_property_labels[j].replace('_',' ')} data found.")
            new_attributes[new_plane_property_labels[j]].append(None)
            continue

        object = get_wikidata_object(plane_entities[i], new_plane_properties[j])
        if object is None:
            print(f"No {new_plane_property_labels[j].replace('_',' ')} data found.")
            new_attributes[new_plane_property_labels[j]].append(None)
        else:
            print(f"{new_plane_property_labels[j].replace('_',' ')}: {object}")
            new_attributes[new_plane_property_labels[j]].append(object)
# Out:
# Extracting new information for aircraft models...
#
# Plane: CRJ-700
# Extracting first flight data...
# first flight: 1999-05-27T00:00:00Z
#
# Plane: CRJ-700
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 12500
#
# Plane: CRJ-700
# Extracting height(m) data...
# height(m): 7.55
#
# Plane: CRJ-700
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-700
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-700
# Extracting total produced data...
# No total produced data found.
#
# Plane: CRJ-700
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: E175-
# Extracting first flight data...
# No first flight data found.
#
# Plane: E175-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: E175-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: E175-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: E175-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: E175-
# Extracting total produced data...
# No total produced data found.
#
# Plane: E175-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-700
# Extracting first flight data...
# No first flight data found.
#
# Plane: B737-700
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-700
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-700
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-700
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-700
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-700
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A320-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A320-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A320-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A320-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A320-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A320-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A320-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: SHORTS-360
# Extracting first flight data...
# first flight: 1981-06-01T00:00:00Z
#
# Plane: SHORTS-360
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 3050
#
# Plane: SHORTS-360
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: SHORTS-360
# Extracting length(m) data...
# length(m): 21.49
#
# Plane: SHORTS-360
# Extracting wingspan(m) data...
# wingspan(m): 22.75
#
# Plane: SHORTS-360
# Extracting total produced data...
# total produced: 165
#
# Plane: SHORTS-360
# Extracting maximum capacity data...
# maximum capacity: 36
#
# Plane: B737-800
# Extracting first flight data...
# first flight: 1997-07-31T00:00:00Z
#
# Plane: B737-800
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-800
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-800
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-800
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-800
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-800
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-700
# Extracting first flight data...
# first flight: 1999-05-27T00:00:00Z
#
# Plane: CRJ-700
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 12500
#
# Plane: CRJ-700
# Extracting height(m) data...
# height(m): 7.55
#
# Plane: CRJ-700
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-700
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-700
# Extracting total produced data...
# No total produced data found.
#
# Plane: CRJ-700
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: A350-900
# Extracting first flight data...
# first flight: 2013-06-14T00:00:00Z
#
# Plane: A350-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A350-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A350-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A350-900
# Extracting wingspan(m) data...
# wingspan(m): 64.75
#
# Plane: A350-900
# Extracting total produced data...
# total produced: 295
#
# Plane: A350-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: A300-B2
# Extracting first flight data...
# No first flight data found.
#
# Plane: A300-B2
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A300-B2
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A300-B2
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A300-B2
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A300-B2
# Extracting total produced data...
# No total produced data found.
#
# Plane: A300-B2
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A321-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A321-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A321-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A321-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A321-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A321-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A321-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: B747-400ER
# Extracting first flight data...
# No first flight data found.
#
# Plane: B747-400ER
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400ER
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B747-400ER
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B747-400ER
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B747-400ER
# Extracting total produced data...
# No total produced data found.
#
# Plane: B747-400ER
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B767-400ER
# Extracting first flight data...
# first flight: 1999-10-09T00:00:00Z
#
# Plane: B767-400ER
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B767-400ER
# Extracting height(m) data...
# height(m): 16.8
#
# Plane: B767-400ER
# Extracting length(m) data...
# length(m): 61.4
#
# Plane: B767-400ER
# Extracting wingspan(m) data...
# wingspan(m): 51.9
#
# Plane: B767-400ER
# Extracting total produced data...
# total produced: 38
#
# Plane: B767-400ER
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-700
# Extracting first flight data...
# No first flight data found.
#
# Plane: B737-700
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-700
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-700
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-700
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-700
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-700
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B787-9
# Extracting first flight data...
# No first flight data found.
#
# Plane: B787-9
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B787-9
# Extracting height(m) data...
# height(m): 17
#
# Plane: B787-9
# Extracting length(m) data...
# length(m): 62.8
#
# Plane: B787-9
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B787-9
# Extracting total produced data...
# No total produced data found.
#
# Plane: B787-9
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B717-
# Extracting first flight data...
# No first flight data found.
#
# Plane: B717-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B717-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B717-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B717-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B717-
# Extracting total produced data...
# No total produced data found.
#
# Plane: B717-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A330-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A330-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A330-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A330-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A330-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A330-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A330-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: CRJ-900
# Extracting first flight data...
# first flight: 2001-02-21T00:00:00Z
#
# Plane: CRJ-900
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 12500
#
# Plane: CRJ-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-900
# Extracting total produced data...
# No total produced data found.
#
# Plane: CRJ-900
# Extracting maximum capacity data...
# maximum capacity: 90
#
# Plane: B767-400ER
# Extracting first flight data...
# first flight: 1999-10-09T00:00:00Z
#
# Plane: B767-400ER
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B767-400ER
# Extracting height(m) data...
# height(m): 16.8
#
# Plane: B767-400ER
# Extracting length(m) data...
# length(m): 61.4
#
# Plane: B767-400ER
# Extracting wingspan(m) data...
# wingspan(m): 51.9
#
# Plane: B767-400ER
# Extracting total produced data...
# total produced: 38
#
# Plane: B767-400ER
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B787-9
# Extracting first flight data...
# No first flight data found.
#
# Plane: B787-9
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B787-9
# Extracting height(m) data...
# height(m): 17
#
# Plane: B787-9
# Extracting length(m) data...
# length(m): 62.8
#
# Plane: B787-9
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B787-9
# Extracting total produced data...
# No total produced data found.
#
# Plane: B787-9
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-900
# Extracting first flight data...
# first flight: 2001-02-21T00:00:00Z
#
# Plane: CRJ-900
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 12500
#
# Plane: CRJ-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-900
# Extracting total produced data...
# No total produced data found.
#
# Plane: CRJ-900
# Extracting maximum capacity data...
# maximum capacity: 90
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A350-900
# Extracting first flight data...
# first flight: 2013-06-14T00:00:00Z
#
# Plane: A350-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A350-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A350-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A350-900
# Extracting wingspan(m) data...
# wingspan(m): 64.75
#
# Plane: A350-900
# Extracting total produced data...
# total produced: 295
#
# Plane: A350-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-900
# Extracting first flight data...
# first flight: 2000-08-03T00:00:00Z
#
# Plane: B737-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-900
# Extracting total produced data...
# total produced: 52
#
# Plane: B737-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-900
# Extracting first flight data...
# first flight: 2000-08-03T00:00:00Z
#
# Plane: B737-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-900
# Extracting total produced data...
# total produced: 52
#
# Plane: B737-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A320-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A320-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A320-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A320-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A320-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A320-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A320-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: E175-
# Extracting first flight data...
# No first flight data found.
#
# Plane: E175-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: E175-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: E175-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: E175-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: E175-
# Extracting total produced data...
# No total produced data found.
#
# Plane: E175-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B767-300
# Extracting first flight data...
# first flight: 1986-01-30T00:00:00Z
#
# Plane: B767-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B767-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B767-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B767-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B767-300
# Extracting total produced data...
# total produced: 104
#
# Plane: B767-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B787-9
# Extracting first flight data...
# No first flight data found.
#
# Plane: B787-9
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B787-9
# Extracting height(m) data...
# height(m): 17
#
# Plane: B787-9
# Extracting length(m) data...
# length(m): 62.8
#
# Plane: B787-9
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B787-9
# Extracting total produced data...
# No total produced data found.
#
# Plane: B787-9
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: DC8-73F
# Extracting first flight data...
# No first flight data found.
#
# Plane: DC8-73F
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: DC8-73F
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: DC8-73F
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: DC8-73F
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: DC8-73F
# Extracting total produced data...
# No total produced data found.
#
# Plane: DC8-73F
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A350-900
# Extracting first flight data...
# first flight: 2013-06-14T00:00:00Z
#
# Plane: A350-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A350-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A350-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A350-900
# Extracting wingspan(m) data...
# wingspan(m): 64.75
#
# Plane: A350-900
# Extracting total produced data...
# total produced: 295
#
# Plane: A350-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-800
# Extracting first flight data...
# first flight: 1997-07-31T00:00:00Z
#
# Plane: B737-800
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-800
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-800
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-800
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-800
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-800
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-900
# Extracting first flight data...
# first flight: 2000-08-03T00:00:00Z
#
# Plane: B737-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-900
# Extracting total produced data...
# total produced: 52
#
# Plane: B737-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-900
# Extracting first flight data...
# first flight: 2000-08-03T00:00:00Z
#
# Plane: B737-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-900
# Extracting total produced data...
# total produced: 52
#
# Plane: B737-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A330-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: A330-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A330-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A330-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A330-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A330-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: A330-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A350-900
# Extracting first flight data...
# first flight: 2013-06-14T00:00:00Z
#
# Plane: A350-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A350-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A350-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A350-900
# Extracting wingspan(m) data...
# wingspan(m): 64.75
#
# Plane: A350-900
# Extracting total produced data...
# total produced: 295
#
# Plane: A350-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A321-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A321-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A321-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A321-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A321-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A321-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A321-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-700
# Extracting first flight data...
# No first flight data found.
#
# Plane: B737-700
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-700
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-700
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-700
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-700
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-700
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: CRJ-900
# Extracting first flight data...
# first flight: 2001-02-21T00:00:00Z
#
# Plane: CRJ-900
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 12500
#
# Plane: CRJ-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-900
# Extracting total produced data...
# No total produced data found.
#
# Plane: CRJ-900
# Extracting maximum capacity data...
# maximum capacity: 90
#
# Plane: A321-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A321-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A321-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A321-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A321-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A321-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A321-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A350-900
# Extracting first flight data...
# first flight: 2013-06-14T00:00:00Z
#
# Plane: A350-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A350-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A350-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A350-900
# Extracting wingspan(m) data...
# wingspan(m): 64.75
#
# Plane: A350-900
# Extracting total produced data...
# total produced: 295
#
# Plane: A350-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A319-
# Extracting first flight data...
# No first flight data found.
#
# Plane: A319-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A319-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A319-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A319-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A319-
# Extracting total produced data...
# No total produced data found.
#
# Plane: A319-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A300-600
# Extracting first flight data...
# No first flight data found.
#
# Plane: A300-600
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A300-600
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A300-600
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A300-600
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A300-600
# Extracting total produced data...
# No total produced data found.
#
# Plane: A300-600
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: B737-900
# Extracting first flight data...
# first flight: 2000-08-03T00:00:00Z
#
# Plane: B737-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-900
# Extracting total produced data...
# total produced: 52
#
# Plane: B737-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B767-400ER
# Extracting first flight data...
# first flight: 1999-10-09T00:00:00Z
#
# Plane: B767-400ER
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B767-400ER
# Extracting height(m) data...
# height(m): 16.8
#
# Plane: B767-400ER
# Extracting length(m) data...
# length(m): 61.4
#
# Plane: B767-400ER
# Extracting wingspan(m) data...
# wingspan(m): 51.9
#
# Plane: B767-400ER
# Extracting total produced data...
# total produced: 38
#
# Plane: B767-400ER
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: A321-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: A321-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A321-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A321-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A321-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: A321-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: A321-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-700
# Extracting first flight data...
# No first flight data found.
#
# Plane: B737-700
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-700
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-700
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-700
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-700
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-700
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-900
# Extracting first flight data...
# first flight: 2000-08-03T00:00:00Z
#
# Plane: B737-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-900
# Extracting total produced data...
# total produced: 52
#
# Plane: B737-900
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: E175-
# Extracting first flight data...
# No first flight data found.
#
# Plane: E175-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: E175-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: E175-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: E175-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: E175-
# Extracting total produced data...
# No total produced data found.
#
# Plane: E175-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: MD-11
# Extracting first flight data...
# No first flight data found.
#
# Plane: MD-11
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: MD-11
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: MD-11
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: MD-11
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: MD-11
# Extracting total produced data...
# No total produced data found.
#
# Plane: MD-11
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: MD-11
# Extracting first flight data...
# No first flight data found.
#
# Plane: MD-11
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: MD-11
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: MD-11
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: MD-11
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: MD-11
# Extracting total produced data...
# No total produced data found.
#
# Plane: MD-11
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: MD-11
# Extracting first flight data...
# No first flight data found.
#
# Plane: MD-11
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: MD-11
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: MD-11
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: MD-11
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: MD-11
# Extracting total produced data...
# No total produced data found.
#
# Plane: MD-11
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: MD-11
# Extracting first flight data...
# No first flight data found.
#
# Plane: MD-11
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: MD-11
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: MD-11
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: MD-11
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: MD-11
# Extracting total produced data...
# No total produced data found.
#
# Plane: MD-11
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: E175-
# Extracting first flight data...
# No first flight data found.
#
# Plane: E175-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: E175-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: E175-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: E175-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: E175-
# Extracting total produced data...
# No total produced data found.
#
# Plane: E175-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B767-300
# Extracting first flight data...
# first flight: 1986-01-30T00:00:00Z
#
# Plane: B767-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B767-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B767-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B767-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B767-300
# Extracting total produced data...
# total produced: 104
#
# Plane: B767-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-900
# Extracting first flight data...
# first flight: 2001-02-21T00:00:00Z
#
# Plane: CRJ-900
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 12500
#
# Plane: CRJ-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-900
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-900
# Extracting total produced data...
# No total produced data found.
#
# Plane: CRJ-900
# Extracting maximum capacity data...
# maximum capacity: 90
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: B737-800
# Extracting first flight data...
# first flight: 1997-07-31T00:00:00Z
#
# Plane: B737-800
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-800
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-800
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-800
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-800
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-800
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: E175-
# Extracting first flight data...
# No first flight data found.
#
# Plane: E175-
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: E175-
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: E175-
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: E175-
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: E175-
# Extracting total produced data...
# No total produced data found.
#
# Plane: E175-
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B777-300
# Extracting first flight data...
# No first flight data found.
#
# Plane: B777-300
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B777-300
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B777-300
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B777-300
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B777-300
# Extracting total produced data...
# No total produced data found.
#
# Plane: B777-300
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B737-800
# Extracting first flight data...
# first flight: 1997-07-31T00:00:00Z
#
# Plane: B737-800
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-800
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-800
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-800
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-800
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-800
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-100
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-100
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-100
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-100
# Extracting length(m) data...
# length(m): 26.77
#
# Plane: CRJ-100
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-100
# Extracting total produced data...
# total produced: 226
#
# Plane: CRJ-100
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: B737-800
# Extracting first flight data...
# first flight: 1997-07-31T00:00:00Z
#
# Plane: B737-800
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B737-800
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B737-800
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B737-800
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B737-800
# Extracting total produced data...
# No total produced data found.
#
# Plane: B737-800
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: B747-400
# Extracting first flight data...
# first flight: 1988-04-29T00:00:00Z
#
# Plane: B747-400
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B747-400
# Extracting height(m) data...
# height(m): 19.4
#
# Plane: B747-400
# Extracting length(m) data...
# length(m): 70.66
#
# Plane: B747-400
# Extracting wingspan(m) data...
# wingspan(m): 64.44
#
# Plane: B747-400
# Extracting total produced data...
# total produced: 694
#
# Plane: B747-400
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: B767-200
# Extracting first flight data...
# No first flight data found.
#
# Plane: B767-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: B767-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: B767-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: B767-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: B767-200
# Extracting total produced data...
# No total produced data found.
#
# Plane: B767-200
# Extracting maximum capacity data...
# No maximum capacity data found.
#
# Plane: EMB-120
# Extracting first flight data...
# first flight: 1983-07-27T00:00:00Z
#
# Plane: EMB-120
# Extracting maximum operating altitude(m) data...
# maximum operating altitude(m): 9085
#
# Plane: EMB-120
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: EMB-120
# Extracting length(m) data...
# length(m): 20
#
# Plane: EMB-120
# Extracting wingspan(m) data...
# wingspan(m): 19.78
#
# Plane: EMB-120
# Extracting total produced data...
# total produced: 354
#
# Plane: EMB-120
# Extracting maximum capacity data...
# maximum capacity: 30
#
# Plane: CRJ-200
# Extracting first flight data...
# first flight: 1991-05-10T00:00:00Z
#
# Plane: CRJ-200
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: CRJ-200
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: CRJ-200
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: CRJ-200
# Extracting wingspan(m) data...
# No wingspan(m) data found.
#
# Plane: CRJ-200
# Extracting total produced data...
# total produced: 1021
#
# Plane: CRJ-200
# Extracting maximum capacity data...
# maximum capacity: 50
#
# Plane: A350-900
# Extracting first flight data...
# first flight: 2013-06-14T00:00:00Z
#
# Plane: A350-900
# Extracting maximum operating altitude(m) data...
# No maximum operating altitude(m) data found.
#
# Plane: A350-900
# Extracting height(m) data...
# No height(m) data found.
#
# Plane: A350-900
# Extracting length(m) data...
# No length(m) data found.
#
# Plane: A350-900
# Extracting wingspan(m) data...
# wingspan(m): 64.75
#
# Plane: A350-900
# Extracting total produced data...
# total produced: 295
#
# Plane: A350-900
# Extracting maximum capacity data...
# No maximum capacity data found.

# %%
for attribute in new_attributes: 
    df[attribute] = new_attributes[attribute]
df.to_csv(aircraft_file_path_simple, index=False)

aircraft_file_path_enriched = 'data/aircraft_models_enriched.csv'
df.to_csv(aircraft_file_path_enriched, index=False)
df
# Out:
#    aircraft_model                   airline            creation_date  \
# 0         CRJ-700          Skywest Airlines  2009-09-10T16:33:00.000
# 1           E175-          Skywest Airlines  2018-04-23T08:34:00.000
# 2        B747-400  KLM Royal Dutch Airlines  2018-04-14T16:49:00.000
# 3        B737-700        Southwest Airlines  2018-03-17T17:20:00.000
# 4        A320-200           United Airlines  2011-08-23T19:20:00.000
# ..            ...                       ...                      ...
# 95       B747-400            Qantas Airways  2009-06-11T02:55:00.000
# 96       B767-200                  Amerijet  2009-11-25T16:10:00.000
# 97        EMB-120          Skywest Airlines  2014-11-01T12:16:00.000
# 98        CRJ-200          Skywest Airlines  2014-04-01T08:35:00.000
# 99       A350-900            Cathay Pacific  2017-12-30T07:08:00.000
#
#             first_flight maximum_operating_altitude(m) height(m) length(m)  \
# 0   1999-05-27T00:00:00Z                         12500      7.55      None
# 1                   None                          None      None      None
# 2   1988-04-29T00:00:00Z                          None      19.4     70.66
# 3                   None                          None      None      None
# 4                   None                          None      None      None
# ..                   ...                           ...       ...       ...
# 95  1988-04-29T00:00:00Z                          None      19.4     70.66
# 96                  None                          None      None      None
# 97  1983-07-27T00:00:00Z                          9085      None        20
# 98  1991-05-10T00:00:00Z                          None      None      None
# 99  2013-06-14T00:00:00Z                          None      None      None
#
#    wingspan(m) total_produced maximum_capacity
# 0         None           None             None
# 1         None           None             None
# 2        64.44            694             None
# 3         None           None             None
# 4         None           None             None
# ..         ...            ...              ...
# 95       64.44            694             None
# 96        None           None             None
# 97       19.78            354               30
# 98        None           1021               50
# 99       64.75            295             None
#
# [100 rows x 10 columns]

# %% [markdown]
# ### Transform to Knowledge Graph

# %%
#Enrich annotations to account for newly added columns
annotations = load_json("annotations/annotations.json")
new_primary_annotations = ["L","L","L","L","L","L","L"]
new_secondary_annotations = ["DATE","FLOAT", "FLOAT", "FLOAT", "FLOAT", "INT", "INT"]

for i in range(len(new_primary_annotations)):
    annotations["primary_annotations"].append(new_primary_annotations[i])
    annotations["secondary_annotations"].append(new_secondary_annotations[i])

wikidata_prop_prefix = "http://www.wikidata.org/prop/direct/"
for col in range(len(new_plane_properties)):
    new_cpa_annotation = ["0", len(cpa) + col + 1, wikidata_prop_prefix + new_plane_properties[col]]
    annotations["cpa"].append(new_cpa_annotation)
    
save_json("annotations/annotations_new.json", annotations)

# %%
import subprocess
import sys

def run_autorml():
    """
    Runs AutoRML via subprocess, simulating the CLI command.
    """
    command = [
        sys.executable, "-m", "autorml",
        "-i", "data/aircraft_models_enriched.csv",
        "-m",
        "-la",
        "-af", "annotations",
        "-ia", "annotations_new.json",
        "-mf", "mappings",            
        "-rf", "rdf",
        "-ds"        
    ]
    
    try:
        # Run the command and capture output
        result = subprocess.run(
            command, 
            check=True, 
            capture_output=True, 
            text=True
        )
        print("AutoRML Output:\n", result.stdout)
    except subprocess.CalledProcessError as e:
        print("Error running AutoRML:\n", e.stderr)

run_autorml()
# Out:
# AutoRML Output:
#  AutoRML initialized!
#
# YARRRML mappings succesfully created!
# RML mappings succesfully created!
#
# YARRRML and RML mappings succesfully generated!
#
# RDF graph succesfully generated!
